# %% [markdown]
# <a href="https://colab.research.google.com/github/cufuentes/CodingDojo/blob/Week-2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
filename = "/content/RailsToTrails_National Count Data_week.xlsx"
bike_df = pd.read_excel(filename)

# %%
bike_df.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
# 3    Week 4 2020-01-20                       75801
# 4    Week 5 2020-01-27                       75841
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                      183546          NaN          0.094627    1.094627
# 1                       97140          NaN          0.179743  117.974253
# 2                       75782          NaN          0.216112  121.611169
# 3                       83809          NaN          0.105645  110.564504
# 4                       94738          NaN          0.249166  124.916602
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# ...

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     datetime64[ns]
#  2    2019 counts (31 counters)  52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     float64
#  6   Unnamed: 6                  52 non-null     float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  1 non-null      float64
#  9   Unnamed: 9                  1 non-null      float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 4.2+ KB

# %%
#limpiamos columnas NUll
bike_df=bike_df.loc[:,"Timeframe":"Change 2019-2020"]

# %%
type(bike_df["Week of"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
date_filter = bike_df["Week of"]> pd.Timestamp(2020,7,31)
bike_df.loc[date_filter,:].info
# Out:
# <bound method DataFrame.info of    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                      167679
# 31   Week 32 2020-08-03                      180605
# 32   Week 33 2020-08-10                      191450
# 33   Week 34 2020-08-17                      168754
# 34   Week 35 2020-08-24                      176624
# 35   Week 36 2020-08-31                      184806
# 36   Week 37 2020-09-07                      157345
# 37   Week 38 2020-09-14                      152527
# 38   Week 39 2020-09-21                      141072
# 39   Week 40 2020-09-28                      135881
# 40   Week 41 2020-10-05                      132239
# 41   Week 42 2020-10-12                      110816
# 42   Week 43 2020-10-19                      110761
# 43   Week 44 2020-10-26                      109795
# 44   Week 45 2020-11-02                      109766
# 45   Week 46 2020-11-09                       86824
# ...

# %%
change19_filter = bike_df["Change 2019-2020"] > 1
bike_df.loc[change19_filter,:].head()
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 7     Week 8 2020-02-17                       69492
# 11   Week 12 2020-03-16                      125440
# 12   Week 13 2020-03-23                      136330
# 13   Week 14 2020-03-30                      118784
# 14   Week 15 2020-04-06                      132033
#
#      2020 counts (31 counters)  2021 Counts  Change 2019-2020
# 7                       149876          NaN          1.156737
# 11                      367795          NaN          1.932039
# 12                      372783          NaN          1.730000
# 13                      280728          NaN          1.360000
# 14                      419160          NaN          2.170000

# %%
df_filter = bike_df.loc[date_filter & change19_filter,:]
df_filter.head()
# Out:
# Empty DataFrame
# Columns: [Timeframe, Week of,  2019 counts (31 counters),  2020 counts (31 counters), 2021 Counts, Change 2019-2020]
# Index: []

# %% [markdown]
# No existen combinaciones con cambio superios al 100% despues de 31-07-2020
